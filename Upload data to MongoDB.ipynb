# %% [markdown]
# ### Test: Push Json data from Open API to MongoDB
#
# This program will get the data from coindesk (open API) every 60 seconds, and push the json data to MongoDB every 60 seconds.

# %%
import requests
import time

from pymongo import MongoClient

client = MongoClient("mongodb://YCH:<Password>@ac-v9dvncc-shard-00-00.6n9k6sk.mongodb.net:27017,ac-v9dvncc-shard-00-01.6n9k6sk.mongodb.net:27017,ac-v9dvncc-shard-00-02.6n9k6sk.mongodb.net:27017/?ssl=true&replicaSet=atlas-gpgpqo-shard-0&authSource=admin&retryWrites=true&w=majority")
db = client.Crypto

while True:
    r=requests.get("https://api.coindesk.com/v1/bpi/currentprice.json")
    if r.status_code == 200:
        data = r.json()
        print(data)
        db.Bitcoin_price.insert_one(data)
        time.sleep(60)
    else:
        exit()
# Out:
# {'time': {'updated': 'Dec 8, 2022 21:24:00 UTC', 'updatedISO': '2022-12-08T21:24:00+00:00', 'updateduk': 'Dec 8, 2022 at 21:24 GMT'}, 'disclaimer': 'This data was produced from the CoinDesk Bitcoin Price Index (USD). Non-USD currency data converted using hourly conversion rate from openexchangerates.org', 'chartName': 'Bitcoin', 'bpi': {'USD': {'code': 'USD', 'symbol': '&#36;', 'rate': '17,186.5051', 'description': 'United States Dollar', 'rate_float': 17186.5051}, 'GBP': {'code': 'GBP', 'symbol': '&pound;', 'rate': '14,360.9062', 'description': 'British Pound Sterling', 'rate_float': 14360.9062}, 'EUR': {'code': 'EUR', 'symbol': '&euro;', 'rate': '16,742.1652', 'description': 'Euro', 'rate_float': 16742.1652}}}
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15136\3733694386.py in <module>
#      12         data = r.json()
# ...

# %% [markdown]
# ### Convert 'Spotify_1.csv' to Json format

# %%
import pandas as pd
import json

df = pd.read_csv('track_info4.csv')
df.assign(Genres=df.genres.str.split(","))
df['duration_min']= df['duration_ms'] / (1000*60)

data = df.to_dict(orient = "records")

data
# Out:
# [{'track_name': 'Unholy (feat. Kim Petras)',
#   'artists': 'Sam Smith, Kim Petras',
#   'track_number': 1,
#   'song_id': '3nqQXoyQOWXiESFLlDF1hG',
#   'added_time': '2022-11-16T12:50:17Z',
#   'popularity': 100,
#   'duration_ms': 156943,
#   'genres': 'dance pop, pop, post-teen pop, transpop',
#   'extracted_at': '25:41.7',
#   'duration_min': 2.6157166666666667},
#  {'track_name': 'Anti-Hero',
#   'artists': 'Taylor Swift',
#   'track_number': 3,
#   'song_id': '0V3wPSX9ygBnCm8psDIegu',
#   'added_time': '2022-11-16T12:50:17Z',
#   'popularity': 97,
#   'duration_ms': 200690,
#   'genres': 'pop',
#   'extracted_at': '25:41.7',
#   'duration_min': 3.3448333333333333},
#  {'track_name': 'Rich Flex',
#   'artists': 'Drake, 21 Savage',
#   'track_number': 1,
#   'song_id': '1bDbXMyjaUIooNwFE9wn0N',
#   'added_time': '2022-11-16T12:50:17Z',
#   'popularity': 92,
#   'duration_ms': 239359,
#   'genres': 'atl hip hop, rap',
#   'extracted_at': '25:41.7',
# ...

# %% [markdown]
# ### Push the Json data (converted from 'Spotify_1.csv') to MongoDB
#
# ##### Note: MongoDB -- database name= 'BDAT1004_Final', collection name = 'Spotify'

# %%
import pandas as pd
import json
from pymongo import MongoClient

client = MongoClient("mongodb://YCH:MON2022@ac-v9dvncc-shard-00-00.6n9k6sk.mongodb.net:27017,ac-v9dvncc-shard-00-01.6n9k6sk.mongodb.net:27017,ac-v9dvncc-shard-00-02.6n9k6sk.mongodb.net:27017/?ssl=true&replicaSet=atlas-gpgpqo-shard-0&authSource=admin&retryWrites=true&w=majority")
db = client.BDAT1004_Final

db.SongData.insert_many(data)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15136\1103677598.py in <module>
#       6 db = client.BDAT1004_Final
#       7
# ----> 8 db.SongData.insert_many(data)
#
# c:\Users\ruwin\anaconda3\lib\site-packages\pymongo\_csot.py in csot_wrapper(self, *args, **kwargs)
#     103                 with _TimeoutContext(timeout):
#     104                     return func(self, *args, **kwargs)
# --> 105         return func(self, *args, **kwargs)
#     106
#     107     return cast(F, csot_wrapper)
#
# c:\Users\ruwin\anaconda3\lib\site-packages\pymongo\collection.py in insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     712         blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     713         blk.ops = [doc for doc in gen()]
# --> 714         blk.execute(write_concern, session=session)
# ...
